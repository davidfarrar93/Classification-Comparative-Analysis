# %%
import pandas as pd

# Load the file path
file_path = 'opel_corsa_01.csv'

# Step 1: Read the first row (header) and data separately
with open(file_path, 'r') as file:
    header_row = file.readline().strip()  # Read the first line as the header row

# Split the header by semicolon to get the column names
column_names = header_row.split(';')

# Now load the data, skipping the first row (header)
df_1 = pd.read_csv(file_path, skiprows=1, header=None, sep=';')  # Load without header

# Step 2: Drop the first column in the data to remove the unnecessary first entry
df_1 = df_1.drop(df_1.columns[0], axis=1)  # Drop the first data column

# Step 3: Shift the header columns one position to the left to align with the data
column_names = column_names[1:]  # Remove the first element in the header list

# Step 4: Ensure header and data columns align
# If the number of columns in the header and data don’t match, we’ll adjust them
if len(column_names) != df_1.shape[1]:
    if len(column_names) > df_1.shape[1]:
        # If header has more columns, truncate it to match the data
        column_names = column_names[:df_1.shape[1]]
    elif len(column_names) < df_1.shape[1]:
        # If header has fewer columns, pad it with generic names
        column_names.extend([f"Unnamed_{i}" for i in range(len(column_names), df.shape[1])])

# Assign corrected column names to the DataFrame
df_1.columns = column_names

# Step 5: Analyze and report errors in the data (e.g., missing values, unusual types)
print("Data Analysis Report:")
print(f"Number of rows: {df_1.shape[0]}")
print(f"Number of columns: {df_1.shape[1]}")
print("Missing values per column:")
print(df_1.isnull().sum())
print("\nData Types:")
print(df_1.dtypes)

# Step 6: Clean the data by separating semicolon-separated values in columns
for column in df_1.columns:
    # Check if any entry in the column contains a semicolon
    if df_1[column].astype(str).str.contains(';').any():
        # Split the column by semicolon into multiple columns
        split_data = df_1[column].str.split(';', expand=True)
        # Rename new columns with original name and an index
        split_data.columns = [f"{column}_{i+1}" for i in range(split_data.shape[1])]
        # Concatenate the new columns with the original DataFrame
        df_1 = pd_1.concat([df_1.drop(column, axis=1), split_data], axis=1)

# Step 7: Print the first 5 rows of the cleaned and type-checked DataFrame
print("\nCleaned and Type-Checked Data (first 5 rows):")
print(df_1.head())

# Step 8: Check final data types after conversion
print("\nFinal Data Types After Conversion:")
print(df_1.dtypes)
# Out:
# Data Analysis Report:
# Number of rows: 7038
# Number of columns: 17
# Missing values per column:
# AltitudeVariation            0
# VehicleSpeedInstantaneous    0
# VehicleSpeedAverage          0
# VehicleSpeedVariance         0
# VehicleSpeedVariation        0
# LongitudinalAcceleration     0
# EngineLoad                   0
# EngineCoolantTemperature     0
# ManifoldAbsolutePressure     0
# EngineRPM                    0
# MassAirFlow                  0
# IntakeAirTemperature         0
# VerticalAcceleration         0
# FuelConsumptionAverage       0
# roadSurface                  0
# traffic                      0
# drivingStyle                 0
# dtype: int64
#
# Data Types:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# ...

# %%
import pandas as pd

# Load the file path
file_path = 'opel_corsa_02.csv'

# Step 1: Read the first row (header) and data separately
with open(file_path, 'r') as file:
    header_row = file.readline().strip()  # Read the first line as the header row

# Split the header by semicolon to get the column names
column_names = header_row.split(';')

# Now load the data, skipping the first row (header)
df_2 = pd.read_csv(file_path, skiprows=1, header=None, sep=';')  # Load without header

# Step 2: Drop the first column in the data to remove the unnecessary first entry
df_2 = df_2.drop(df_2.columns[0], axis=1)  # Drop the first data column

# Step 3: Shift the header columns one position to the left to align with the data
column_names = column_names[1:]  # Remove the first element in the header list

# Step 4: Ensure header and data columns align
# If the number of columns in the header and data don’t match, we’ll adjust them
if len(column_names) != df_2.shape[1]:
    if len(column_names) > df_2.shape[1]:
        # If header has more columns, truncate it to match the data
        column_names = column_names[:df_2.shape[1]]
    elif len(column_names) < df_2.shape[1]:
        # If header has fewer columns, pad it with generic names
        column_names.extend([f"Unnamed_{i}" for i in range(len(column_names), df_2.shape[1])])

# Assign corrected column names to the DataFrame
df_2.columns = column_names

# Step 5: Analyze and report errors in the data (e.g., missing values, unusual types)
print("Data Analysis Report:")
print(f"Number of rows: {df_2.shape[0]}")
print(f"Number of columns: {df_2.shape[1]}")
print("Missing values per column:")
print(df_2.isnull().sum())
print("\nData Types:")
print(df_2.dtypes)

# Step 6: Clean the data by separating semicolon-separated values in columns
for column in df_2.columns:
    # Check if any entry in the column contains a semicolon
    if df_2[column].astype(str).str.contains(';').any():
        # Split the column by semicolon into multiple columns
        split_data = df_2[column].str.split(';', expand=True)
        # Rename new columns with original name and an index
        split_data.columns = [f"{column}_{i+1}" for i in range(split_data.shape[1])]
        # Concatenate the new columns with the original DataFrame
        df_2 = pd.concat([df_2.drop(column, axis=1), split_data], axis=1)

# Step 7: Print the first 5 rows of the cleaned and type-checked DataFrame
print("\nCleaned and Type-Checked Data (first 5 rows):")
print(df_2.head())

# Step 8: Check final data types after conversion
print("\nFinal Data Types After Conversion:")
print(df_2.dtypes)
# Out:
# Data Analysis Report:
# Number of rows: 4092
# Number of columns: 17
# Missing values per column:
# AltitudeVariation            0
# VehicleSpeedInstantaneous    0
# VehicleSpeedAverage          0
# VehicleSpeedVariance         0
# VehicleSpeedVariation        0
# LongitudinalAcceleration     0
# EngineLoad                   0
# EngineCoolantTemperature     0
# ManifoldAbsolutePressure     0
# EngineRPM                    0
# MassAirFlow                  0
# IntakeAirTemperature         0
# VerticalAcceleration         0
# FuelConsumptionAverage       0
# roadSurface                  0
# traffic                      0
# drivingStyle                 0
# dtype: int64
#
# Data Types:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# ...

# %%
import pandas as pd

# Load the file path
file_path = 'peugeot_207_01.csv'

# Step 1: Read the first row (header) and data separately
with open(file_path, 'r') as file:
    header_row = file.readline().strip()  # Read the first line as the header row

# Split the header by semicolon to get the column names
column_names = header_row.split(';')

# Now load the data, skipping the first row (header)
df_3 = pd.read_csv(file_path, skiprows=1, header=None, sep=';')  # Load without header

# Step 2: Drop the first column in the data to remove the unnecessary first entry
df_3 = df_3.drop(df_3.columns[0], axis=1)  # Drop the first data column

# Step 3: Shift the header columns one position to the left to align with the data
column_names = column_names[1:]  # Remove the first element in the header list

# Step 4: Ensure header and data columns align
# If the number of columns in the header and data don’t match, we’ll adjust them
if len(column_names) != df_3.shape[1]:
    if len(column_names) > df_3.shape[1]:
        # If header has more columns, truncate it to match the data
        column_names = column_names[:df_3.shape[1]]
    elif len(column_names) < df_3.shape[1]:
        # If header has fewer columns, pad it with generic names
        column_names.extend([f"Unnamed_{i}" for i in range(len(column_names), df_3.shape[1])])

# Assign corrected column names to the DataFrame
df_3.columns = column_names

# Step 5: Analyze and report errors in the data (e.g., missing values, unusual types)
print("Data Analysis Report:")
print(f"Number of rows: {df_3.shape[0]}")
print(f"Number of columns: {df_3.shape[1]}")
print("Missing values per column:")
print(df_3.isnull().sum())
print("\nData Types:")
print(df_3.dtypes)

# Step 6: Clean the data by separating semicolon-separated values in columns
for column in df_3.columns:
    # Check if any entry in the column contains a semicolon
    if df_3[column].astype(str).str.contains(';').any():
        # Split the column by semicolon into multiple columns
        split_data = df_3[column].str.split(';', expand=True)
        # Rename new columns with original name and an index
        split_data.columns = [f"{column}_{i+1}" for i in range(split_data.shape[1])]
        # Concatenate the new columns with the original DataFrame
        df_3 = pd.concat([df_3.drop(column, axis=1), split_data], axis=1)
    df_3.dropna(inplace=True)

# Step 7: Print the first 5 rows of the cleaned and type-checked DataFrame
print("\nCleaned and Type-Checked Data (first 5 rows):")
print(df_3.head())

# Step 8: Check final data types after conversion
print("\nFinal Data Types After Conversion:")
print(df_3.dtypes)

# Step 9: Recheck missing values
print("\nRecheck Null Values:")
print(df_3.isnull().sum())
# Out:
# Data Analysis Report:
# Number of rows: 8199
# Number of columns: 17
# Missing values per column:
# AltitudeVariation            0
# VehicleSpeedInstantaneous    3
# VehicleSpeedAverage          0
# VehicleSpeedVariance         0
# VehicleSpeedVariation        0
# LongitudinalAcceleration     0
# EngineLoad                   5
# EngineCoolantTemperature     5
# ManifoldAbsolutePressure     5
# EngineRPM                    5
# MassAirFlow                  5
# IntakeAirTemperature         5
# VerticalAcceleration         0
# FuelConsumptionAverage       5
# roadSurface                  0
# traffic                      0
# drivingStyle                 0
# dtype: int64
#
# Data Types:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# ...

# %%
import pandas as pd

# Load the file path
file_path = 'peugeot_207_02.csv'

# Step 1: Read the first row (header) and data separately
with open(file_path, 'r') as file:
    header_row = file.readline().strip()  # Read the first line as the header row

# Split the header by semicolon to get the column names
column_names = header_row.split(';')

# Now load the data, skipping the first row (header)
df_4 = pd.read_csv(file_path, skiprows=1, header=None, sep=';')  # Load without header

# Step 2: Drop the first column in the data to remove the unnecessary first entry
df_4 = df_4.drop(df_4.columns[0], axis=1)  # Drop the first data column

# Step 3: Shift the header columns one position to the left to align with the data
column_names = column_names[1:]  # Remove the first element in the header list

# Step 4: Ensure header and data columns align
# If the number of columns in the header and data don’t match, we’ll adjust them
if len(column_names) != df_4.shape[1]:
    if len(column_names) > df_4.shape[1]:
        # If header has more columns, truncate it to match the data
        column_names = column_names[:df_4.shape[1]]
    elif len(column_names) < df_4.shape[1]:
        # If header has fewer columns, pad it with generic names
        column_names.extend([f"Unnamed_{i}" for i in range(len(column_names), df_4.shape[1])])

# Assign corrected column names to the DataFrame
df_4.columns = column_names

# Step 5: Analyze and report errors in the data (e.g., missing values, unusual types)
print("Data Analysis Report:")
print(f"Number of rows: {df_4.shape[0]}")
print(f"Number of columns: {df_4.shape[1]}")
print("Missing values per column:")
print(df_4.isnull().sum())
print("\nData Types:")
print(df_4.dtypes)

# Step 6: Clean the data by separating semicolon-separated values in columns
for column in df_4.columns:
    # Check if any entry in the column contains a semicolon
    if df_4[column].astype(str).str.contains(';').any():
        # Split the column by semicolon into multiple columns
        split_data = df_4[column].str.split(';', expand=True)
        # Rename new columns with original name and an index
        split_data.columns = [f"{column}_{i+1}" for i in range(split_data.shape[1])]
        # Concatenate the new columns with the original DataFrame
        df_4 = pd.concat([df_4.drop(column, axis=1), split_data], axis=1)
    df_4.dropna(inplace=True)

# Step 7: Print the first 5 rows of the cleaned and type-checked DataFrame
print("\nCleaned and Type-Checked Data (first 5 rows):")
print(df_4.head())

# Step 8: Check final data types after conversion
print("\nFinal Data Types After Conversion:")
print(df_4.dtypes)

# Step 9: Recheck missing values
print("\nRecheck Null Values:")
print(df_4.isnull().sum())
# Out:
# Data Analysis Report:
# Number of rows: 4446
# Number of columns: 17
# Missing values per column:
# AltitudeVariation            0
# VehicleSpeedInstantaneous    6
# VehicleSpeedAverage          0
# VehicleSpeedVariance         0
# VehicleSpeedVariation        0
# LongitudinalAcceleration     0
# EngineLoad                   0
# EngineCoolantTemperature     0
# ManifoldAbsolutePressure     0
# EngineRPM                    0
# MassAirFlow                  0
# IntakeAirTemperature         0
# VerticalAcceleration         0
# FuelConsumptionAverage       0
# roadSurface                  0
# traffic                      0
# drivingStyle                 0
# dtype: int64
#
# Data Types:
# AltitudeVariation            float64
# VehicleSpeedInstantaneous    float64
# VehicleSpeedAverage          float64
# VehicleSpeedVariance         float64
# VehicleSpeedVariation        float64
# LongitudinalAcceleration     float64
# EngineLoad                   float64
# ...

# %%
# Add identifiers for vehicle type and journey number
df_1['Vehicle'] = 'Opel Corsa'
df_1['Journey'] = 'Journey 1'

df_2['Vehicle'] = 'Opel Corsa'
df_2['Journey'] = 'Journey 2'

df_3['Vehicle'] = 'Peugeot 207'
df_3['Journey'] = 'Journey 1'

df_4['Vehicle'] = 'Peugeot 207'
df_4['Journey'] = 'Journey 2'

# Merge DataFrames with the new identifier columns
combined_df = pd.concat([df_1, df_2, df_3, df_4], ignore_index=True)

# Check the result
print(combined_df.head())

#Check length of dataframes to confirm merge sucessful

print("\nLength of df_1")
print(len(df_1))
print("\nLength of df_2")
print(len(df_2))
print("\nLength of df_3")
print(len(df_3))
print("\nLength of df_4")
print(len(df_4))
print("\nLength of combined_df")
print(len(combined_df))
# Out:
#    AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# 0          -2.299988                  25.670519            13.223501
# 1          -2.099976                  24.094259            13.638919
# 2          -1.500000                  22.743179            14.031043
# 3           0.100037                  22.292820            14.171073
# 4           0.099976                  23.643900            14.328954
#
#    VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# 0            121.592690              -2.476980                    0.3555
# 1            120.422571              -1.576260                    0.4492
# 2            118.456769              -1.351080                    0.4258
# 3            117.571308              -0.450359                    0.4140
# 4            117.074149               1.351080                    0.3945
#
#    EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# ...

# %%
# Display basic statistics for each feature
print("Basic Statistics of each feature:")
print(combined_df.describe())

# Check for missing values in each column
print("\nMissing values in each column:")
print(combined_df.isnull().sum())
# Out:
# Basic Statistics of each feature:
#        AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# count       23762.000000               23762.000000         23762.000000
# mean           -0.263387                  38.651043            38.813804
# std             2.091693                  33.863575            31.148168
# min           -24.600006                   0.000000             0.000000
# 25%            -1.399998                  11.700000            15.996519
# 50%            -0.099998                  31.500000            29.325470
# 75%             0.700001                  54.899998            50.159999
# max            11.400002                 124.749725           121.330733
#
#        VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# count          23762.000000           23762.000000              23762.000000
# mean             171.961782              -0.014447                  0.681711
# ...

# %%
# Checking Data for Traffic Column

# Check the distribution of classes in the "Traffic" column
print("Class distribution in the 'Traffic' column:")
print(combined_df['traffic'].value_counts())

# Optional: Display the distribution as a percentage for a clearer view of class imbalance
print("\nClass distribution as a percentage:")
print(combined_df['traffic'].value_counts(normalize=True) * 100)
# Out:
# Class distribution in the 'Traffic' column:
# traffic
# LowCongestionCondition       17757
# HighCongestionCondition       3015
# NormalCongestionCondition     2990
# Name: count, dtype: int64
#
# Class distribution as a percentage:
# traffic
# LowCongestionCondition       74.728558
# HighCongestionCondition      12.688326
# NormalCongestionCondition    12.583116
# Name: proportion, dtype: float64

# %% [markdown]
# Significant imbalance here, where the low congestion condition has signifiantly more samples than the normal and high conditions.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a count plot for the 'Traffic' classes
plt.figure(figsize=(8,6))
sns.countplot(x='traffic', data=combined_df)

# Add titles and labels
plt.title('Traffic Class Distribution')
plt.xlabel('Traffic Class')
plt.ylabel('Number of Samples')

# Show the plot
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Step 1: Encode categorical columns
for col in ['roadSurface', 'drivingStyle', 'Vehicle', 'Journey']:
    combined_df[col] = LabelEncoder().fit_transform(combined_df[col])

# Step 2: Define features (X) and target (y) with 'Traffic' as the target column
X = combined_df.drop(columns=['traffic'])
y = combined_df['traffic']

# Step 3: Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Step 4: Scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Step 5: Initialize and train the Logistic Regression model with class weighting and increased max_iter
logistic_model = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)
logistic_model.fit(X_train, y_train)

# Step 6: Initialize and train the SVM model with class weighting
svm_model = SVC(class_weight='balanced', random_state=42)
svm_model.fit(X_train, y_train)

# Step 7: Evaluate models on the test set
# Logistic Regression evaluation
y_pred_logistic = logistic_model.predict(X_test)
print("Logistic Regression Performance:")
print("Accuracy:", accuracy_score(y_test, y_pred_logistic))
print(classification_report(y_test, y_pred_logistic))

# SVM evaluation
y_pred_svm = svm_model.predict(X_test)
print("\nSVM Performance:")
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# Logistic Regression Performance:
# Accuracy: 0.7428992215442878
#                            precision    recall  f1-score   support
#
#   HighCongestionCondition       0.47      0.81      0.59       603
#    LowCongestionCondition       0.96      0.73      0.83      3552
# NormalCongestionCondition       0.46      0.78      0.58       598
#
#                  accuracy                           0.74      4753
#                 macro avg       0.63      0.77      0.67      4753
#              weighted avg       0.83      0.74      0.76      4753
#
#
# SVM Performance:
# Accuracy: 0.9440353460972017
#                            precision    recall  f1-score   support
#
#   HighCongestionCondition       0.82      0.96      0.88       603
#    LowCongestionCondition       0.99      0.94      0.97      3552
# NormalCongestionCondition       0.84      0.93      0.88       598
#
#                  accuracy                           0.94      4753
# ...
